# %%
def amplitude(vetor):
    amplitude = max(vetor) - min(vetor)
    return amplitude

vetor = [12,23,45,2,100]
print(f'A Amplitude é: {amplitude(vetor)}')
# Out:
# A Amplitude é: 98

# %%
def decomposicao(texto): 
    for i in range(len(texto)):
        print(texto[i])
        
decomposicao("Python")
# Out:
# P
# y
# t
# h
# o
# n

# %%
peso = 10

if peso == 10: 
    print('Você pagará R$ 50')
elif peso >= 11 and peso <= 20:
    print('o valor será de R$ 80')
else: 
    print('não permitido')
# Out:
# Você pagará R$ 50
